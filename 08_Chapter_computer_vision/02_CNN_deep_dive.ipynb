# %%
# Şimdi bir CNN deep dive yapacağız mimariyi daha dikkatli inceleyeceğiz.
# Hesaplamaları aslında kontrol edeceğiz.
import torch
from torch import nn
import torchvision
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
torch.manual_seed(42)

images = torch.randn(size=(32,3,32,32)) # [batch_size, color_channels, heigth, width]
test_image = images[0]
print(f"Image batch shape: {images.shape} -> [batch_size, color_channels, heigth, width]") 
print(f"Sıngle Image shape: {test_image.shape} -> [color_channels, heigth, width]")
# Out:
# Image batch shape: torch.Size([32, 3, 32, 32]) -> [batch_size, color_channels, heigth, width]
# Sıngle Image shape: torch.Size([3, 32, 32]) -> [color_channels, heigth, width]

# %%
torch.manual_seed(42)

conv_layer = nn.Conv2d(in_channels = 3,
                    out_channels = 10,
                    kernel_size = 3,
                    stride= 1,
                    padding=0
                    )

# %%
conv_layer(test_image).shape
# Out:
# torch.Size([10, 30, 30])

# %%
test_image.shape
# Out:
# torch.Size([3, 32, 32])

# %%
x = torch.randn(1,3,64,64)
print("Input: ",x.shape)
# Out:
# Input:  torch.Size([1, 3, 64, 64])

# %%
conv1 = nn.Conv2d(in_channels=3,
                      out_channels=10,
                      kernel_size=3, 
                      stride=1,
                      padding=0)

conv2 = nn.Conv2d(in_channels=10,
                      out_channels=10,
                      kernel_size=3, 
                      stride=1,
                      padding=0)

pool1 = nn.MaxPool2d(kernel_size=2,
                    stride = 2)
                
x = conv1(x)
print("After Conv1:", x.shape)

x = conv2(x)
print("After Conv2:", x.shape)

x = pool1(x)
print("After pool1:", x.shape)

conv3 = nn.Conv2d(in_channels=10,
                      out_channels=10,
                      kernel_size=3, 
                      stride=1,
                      padding=0)

conv4 = nn.Conv2d(in_channels=10,
                      out_channels=10,
                      kernel_size=3, 
                      stride=1,
                      padding=0)

pool2 = nn.MaxPool2d(kernel_size=2,
                    stride = 2)
                
x = conv3(x)
print("After Conv3:", x.shape)

x = conv4(x)
print("After Conv4:", x.shape)

x = pool2(x)
print("After pool2:", x.shape)
# Şu an VGG mimarisini simüle etmiş olduk aslında shape kısmını yani.
# Out:
# After Conv1: torch.Size([1, 10, 62, 62])
# After Conv2: torch.Size([1, 10, 60, 60])
# After pool1: torch.Size([1, 10, 30, 30])
# After Conv3: torch.Size([1, 10, 28, 28])
# After Conv4: torch.Size([1, 10, 26, 26])
# After pool2: torch.Size([1, 10, 13, 13])
